# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
data = pd.read_csv('dataset.csv')

# %%
data.shape
# Out:
# (30, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Kecamatan            30 non-null     object
#  1   UPT_Puskesmas        30 non-null     object
#  2   Cek_Tekanan_Darah_L  30 non-null     int64
#  3   Cek_Tekanan_Darah_P  30 non-null     int64
#  4   Hipertensi_L         30 non-null     int64
#  5   Hipertensi_P         30 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 1.5+ KB

# %%
# DATA PENGUKURAN TEKANAN DARAH DI BANDUNG
data
# Out:
#            Kecamatan          UPT_Puskesmas  Cek_Tekanan_Darah_L  \
# 0           Sukasari           UPT Sukarasa                   14
# 1           Sukajadi          UPT Sukajadi                    27
# 2            Cicendo        UPT Pasirkaliki                 1924
# 3              Andir             UPT Garuda                  154
# 4            Cidadap       UPT Ciumbuleuit                  1858
# 5            Coblong             UPT Puter                    12
# 6      Bandung Wetan              UPT Salam                  155
# 7      Sumur Bandung           UPT Tamblong                  176
# 8   Cibeunying Kaler         UPT Neglasari                   931
# 9   Cibeunying Kidul           UPT Padasuka                   68
# 10      Kiaracondong       UPT Babakan Sari                  445
# 11       Batununggal       UPT Ibrahim Aji                   736
# 12          Lengkong        UPT Talagabodas                   98
# ...

# %%
data.head()
# Out:
#   Kecamatan     UPT_Puskesmas  Cek_Tekanan_Darah_L  Cek_Tekanan_Darah_P  \
# 0  Sukasari      UPT Sukarasa                   14                  425
# 1  Sukajadi     UPT Sukajadi                    27                  319
# 2   Cicendo   UPT Pasirkaliki                 1924                 7733
# 3     Andir        UPT Garuda                  154                  524
# 4   Cidadap  UPT Ciumbuleuit                  1858                 1681
#
#    Hipertensi_L  Hipertensi_P
# 0             8           117
# 1            19            91
# 2           390          1503
# 3            40            75
# 4           927           790

# %%
data.describe()
# Out:
#        Cek_Tekanan_Darah_L  Cek_Tekanan_Darah_P  Hipertensi_L  Hipertensi_P
# count             30.00000            30.000000     30.000000     30.000000
# mean             504.90000          1138.866667    120.200000    218.666667
# std              658.50805          1544.738919    202.064414    302.455278
# min               12.00000           142.000000      5.000000     21.000000
# 25%               82.25000           324.000000     18.250000     68.000000
# 50%              165.50000           511.000000     40.000000    104.000000
# 75%              663.25000          1568.500000     62.000000    224.750000
# max             1924.00000          7733.000000    927.000000   1503.000000

# %%
df = pd.DataFrame(data)
df_akhir = df.assign(Persentase_L = df['Hipertensi_L']/df['Cek_Tekanan_Darah_L']*100)
plt.bar(df_akhir.Kecamatan, df_akhir.Persentase_L)
plt.xlabel('Persentase Laki Laki Terkena Hipertensi')
plt.show()
